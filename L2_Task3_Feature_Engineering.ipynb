# %% [markdown]
# Step 1: Import and load Dataset

# %%
import pandas as pd
df = pd.read_csv('/content/Dataset.csv')
df.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %% [markdown]
# Step 2: Check Dataset Information

# %%
print("Dataset Shape:", df.shape)
print("\nColumns:")
print(df.columns)
# Out:
# Dataset Shape: (9551, 21)
#
# Columns:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %% [markdown]
# Step 3: Create Feature - Restaurant Name Length

# %%
df['Restaurant_Name_Length'] = df['Restaurant Name'].astype(str).apply(len)

df[['Restaurant Name', 'Restaurant_Name_Length']].head()
# Out:
#           Restaurant Name  Restaurant_Name_Length
# 0        Le Petit Souffle                      16
# 1        Izakaya Kikufuji                      16
# 2  Heat - Edsa Shangri-La                      22
# 3                    Ooma                       4
# 4             Sambo Kojin                      11

# %% [markdown]
# Step 4: Create Feature - Restaurant Address Length

# %%
df['Address_Length'] = df['Address'].astype(str).apply(len)

df[['Address', 'Address_Length']].head()
# Out:
#                                              Address  Address_Length
# 0  Third Floor, Century City Mall, Kalayaan Avenu...              71
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...              67
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...              56
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...              70
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...              64

# %% [markdown]
# Step 5: Create Feature - Number of Cuisines Offered

# %%
df['Number_of_Cuisines'] = df['Cuisines'].astype(str).apply(lambda x: len(x.split(',')))

df[['Cuisines', 'Number_of_Cuisines']].head()
# Out:
#                            Cuisines  Number_of_Cuisines
# 0        French, Japanese, Desserts                   3
# 1                          Japanese                   1
# 2  Seafood, Asian, Filipino, Indian                   4
# 3                   Japanese, Sushi                   2
# 4                  Japanese, Korean                   2

# %% [markdown]
# Step 6: Encode "Has Table Booking"

# %%
df['Has_Table_Booking_Encoded'] = df['Has Table booking'].map({
    'Yes': 1,
    'No': 0
})

df[['Has Table booking', 'Has_Table_Booking_Encoded']].head()
# Out:
#   Has Table booking  Has_Table_Booking_Encoded
# 0               Yes                          1
# 1               Yes                          1
# 2               Yes                          1
# 3                No                          0
# 4               Yes                          1

# %% [markdown]
# Step 7: Encode "Has Online Delivery"

# %%
df['Has_Online_Delivery_Encoded'] = df['Has Online delivery'].map({
    'Yes': 1,
    'No': 0
})

df[['Has Online delivery', 'Has_Online_Delivery_Encoded']].head()
# Out:
#   Has Online delivery  Has_Online_Delivery_Encoded
# 0                  No                            0
# 1                  No                            0
# 2                  No                            0
# 3                  No                            0
# 4                  No                            0

# %% [markdown]
# Step 8: Encode "Is Delivering Now"

# %%
df['Is_Delivering_Now_Encoded'] = df['Is delivering now'].map({
    'Yes': 1,
    'No': 0
})

df[['Is delivering now', 'Is_Delivering_Now_Encoded']].head()
# Out:
#   Is delivering now  Is_Delivering_Now_Encoded
# 0                No                          0
# 1                No                          0
# 2                No                          0
# 3                No                          0
# 4                No                          0

# %% [markdown]
# Step 9: View Newly Created Features

# %%
new_features = [
    'Restaurant_Name_Length',
    'Address_Length',
    'Number_of_Cuisines',
    'Has_Table_Booking_Encoded',
    'Has_Online_Delivery_Encoded',
    'Is_Delivering_Now_Encoded'
]

df[new_features].head()
# Out:
#    Restaurant_Name_Length  Address_Length  Number_of_Cuisines  \
# 0                      16              71                   3
# 1                      16              67                   1
# 2                      22              56                   4
# 3                       4              70                   2
# 4                      11              64                   2
#
#    Has_Table_Booking_Encoded  Has_Online_Delivery_Encoded  \
# 0                          1                            0
# 1                          1                            0
# 2                          1                            0
# 3                          0                            0
# 4                          1                            0
#
#    Is_Delivering_Now_Encoded
# 0                          0
# 1                          0
# 2                          0
# 3                          0
# 4                          0

# %% [markdown]
# Step 10: Save Feature Engineered Dataset

# %%
df.to_csv('Feature_Engineered_Restaurants.csv', index=False)

print("Feature engineered dataset saved successfully!")
# Out:
# Feature engineered dataset saved successfully!
